# %%
#Вам необходимо написать программу, которая находит длину третьей стороны произвольного треугольника по двум его сторонам и углу между ними.
# Можно использовать для этого теорему косинусов.
#Таким образом, программа должна спрашивать пользователя параметры треугольника:
# длину первой стороны, длину второй стороны и угол между ними в градусах.

import math
from math import cos, pi, sqrt, degrees, radians

a = input("Введи длину первой стороны треугольника: ")
b = input("Введи длину второй стороны треугольника: ")
c = input("Введите угол: ")
a = int(a)
b = int(b)
c = int(c)

c = radians(c) #переводит из градусов в радианы т.к. функция косинуса работает только с ними

print("Косинус заданного угла: ", cos(c))

z = sqrt(a ** 2 + b ** 2 - 2*a*b*cos(c)) #извлекает квадратный корень

print("Длина третьей стороны угла: ", round(z))

# функция round (число или переменная, количество чисел после запятой)
# Out:
# Введи длину первой стороны треугольника: 5
# Введи длину второй стороны треугольника: 5
# Введите угол: 60
# Косинус заданного угла:  0.5000000000000001
# Длина третьей стороны угла:  5

# %%
#Выберите одну из формул из математики. Напишите программу с использованием переменных.
#найти площадь и периметр прямоугольниа

a = input("Введи длину первой стороны прямоугольника: ")
b = input("Введи длину второй стороны прямоугольника: ")
a = int(a)
b = int(b)

S = a * b
S = int(S)

P = 2*(a+b)
P = int(P)

print("Площадь прямоугольника = ", S)
print("Периметр прямоугольника = ", P)
# Out:
# Введи длину первой стороны прямоугольника: 6
# Введи длину второй стороны прямоугольника: 7
# Площадь прямоугольника =  42
# Периметр прямоугольника =  26
